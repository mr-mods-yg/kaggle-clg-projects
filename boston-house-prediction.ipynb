# %% [markdown]
# # Lab 1 : Implement and demonstrate Linear Regression and variable correlation for House Price Prediction using sklearn Read the training data from a BostonHouse.CSV file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# load the dataset
df = pd.read_csv('https://www.kaggle.com/code/mrmods/boston-house-prediction/edit')

# %%
df.shape
# Out:
# (506, 14)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
# display the summary statistics of the dataset
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  501.000000  501.000000  501.000000  501.000000  501.000000  501.000000
# mean     3.647414   11.402196   11.160619    0.069860    0.555151    6.284341
# std      8.637688   23.414214    6.857123    0.255166    0.116186    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081990    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.261690    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.693110   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  501.000000  501.000000  501.000000  501.000000  501.000000  501.000000
# mean    68.513373    3.786423    9.596806  409.143713   18.453493  356.298523
# ...

# %%
plt.figure(figsize=(18,6))
sns.histplot(df['medv'], kde=True)
plt.title('Distribution of House Prices')
plt.xlabel('House Prices')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
correlation_matrix = df.corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
